# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('/content/mushrooms.csv')
df.head(n=10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %%
data = df.sample(frac=0.75, random_state=None).reset_index(drop=True)
data_unseen = df.drop(data.index).reset_index(drop=True)
print("Data for Modeling :" + str(data.shape))
print("Unseen Data for Prediction :" + str(data_unseen.shape))
# Out:
# Data for Modeling :(6093, 23)
# Unseen Data for Prediction :(2031, 23)

# %% [markdown]
# # AutoML
# # Pycaret
# # FBpropthet
# # DARTS

# %%
# !pip install pycaret

# %%
from pycaret.classification import *

# %%
exp_clf101 = setup(data=data, target='class', session_id=130)
# Out:
# <style type="text/css">
# #T_5bd17_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5bd17" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bd17_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5bd17_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bd17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bd17_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5bd17_row0_col1" class="data row0 col1" >130</td>
#     </tr>
#     <tr>
#       <th id="T_5bd17_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bd17_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5bd17_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_5bd17_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_7833d th {
#   text-align: left;
# }
# #T_7833d_row0_col0, #T_7833d_row1_col0, #T_7833d_row2_col0, #T_7833d_row3_col0, #T_7833d_row3_col2, #T_7833d_row4_col0, #T_7833d_row5_col0, #T_7833d_row6_col0, #T_7833d_row7_col0, #T_7833d_row8_col0, #T_7833d_row9_col0, #T_7833d_row10_col0, #T_7833d_row11_col0, #T_7833d_row11_col1, #T_7833d_row11_col2, #T_7833d_row11_col3, #T_7833d_row11_col5, #T_7833d_row11_col6, #T_7833d_row11_col7, #T_7833d_row12_col0, #T_7833d_row12_col1, #T_7833d_row12_col3, #T_7833d_row12_col5, #T_7833d_row12_col6, #T_7833d_row12_col7, #T_7833d_row13_col0, #T_7833d_row13_col1, #T_7833d_row13_col2, #T_7833d_row13_col3, #T_7833d_row13_col4, #T_7833d_row13_col5, #T_7833d_row13_col6, #T_7833d_row13_col7, #T_7833d_row14_col0, #T_7833d_row14_col1, #T_7833d_row14_col2, #T_7833d_row14_col3, #T_7833d_row14_col4, #T_7833d_row14_col5, #T_7833d_row14_col6, #T_7833d_row14_col7 {
#   text-align: left;
# }
# ...
